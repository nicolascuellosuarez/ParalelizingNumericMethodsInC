// %%
#include <stdio.h>
#include <omp.h>

int main() {
    #pragma omp parallel
    {
        printf("Hola desde el hilo: %d\n", omp_get_thread_num());
    }

    return 0;
}
// Out:
// /tmp/tmp6qxx9ag2.out: symbol lookup error: /tmp/tmp1o4exof5.out: undefined symbol: omp_get_thread_num
// [C kernel] Executable exited with code 127
